# %%
import numpy as np
import matplotlib.pyplot as plt


def read_reg_file(file_path):
    """
    Reads a .reg file, skips comments, and extracts columns into NumPy arrays.
    """
    wavelengths = []
    fluxes = []
    fitted_fluxes = []
    errors = []

    with open(file_path, 'r') as file:
        for line in file:
            # Skip comments
            if line.startswith('#'):
                continue
            
            # Split the line into columns
            parts = line.split()
            if len(parts) >= 4:  # Ensure we have enough columns
                wavelengths.append(float(parts[0]))
                fluxes.append(float(parts[1]))
                fitted_fluxes.append(float(parts[2]))
                errors.append(float(parts[3]))
    
    return np.array(wavelengths), np.array(fluxes), np.array(fitted_fluxes), np.array(errors)

# %% [markdown]
# ## The fits and parameters

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 75860_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-75860')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# ratio calculator for 1st component 75860
log_12CHp = 13.3838 
del_log12CHp = 0.0553

log_13CHp = 11.6754  
del_log13CHp = 0.1245


max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('-----------------------------------------------------')

# ratio calculator for 2nd component 75860
log_12CHp = 13.6046 
del_log12CHp = 0.0359

log_13CHp = 11.8073 
del_log13CHp = 0.1119

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 2.7485269519646787 2.4199143783392216 2.1305905675427255 max, fit, min 10^13
# 0.06308120779076946 0.047358724812533566 0.03555494408585933 max, fit, min 10^13
# Ratio =  51.097540905467696
# upper bound = 77.30364996011353 lower bound = 33.775361033186975
# -----------------------------------------------------
# 4.3701867907061285 4.023462889902309 3.704247530299583 max, fit, min 10^13
# 0.08302330159249538 0.06416526614874048 0.049590672750490325 max, fit, min 10^13
# Ratio =  62.70468637308514
# upper bound = 88.12517653660825 lower bound = 44.61696245809641

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 147889_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('147889')
plt.show()

# ratio calculator for 147889
log_12CHp = 13.5321 
del_log12CHp = 0.0043 

log_13CHp = 12.0183 
del_log13CHp = 0.0828 

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13)

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13)

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 3.4387452222912755 3.404865806080549 3.371320178728428
# 0.1262118114570753 0.10430376855048382 0.08619855787057572
# Ratio =  32.64374675429458
# upper bound = 39.893303406008684 lower bound = 26.71160598843806

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 183143_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-183143')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# has only one component with good ratio

# ratio calculator for 183143
log_12CHp = 13.4918
del_log12CHp = 0.0346

log_13CHp = 11.7891
del_log13CHp = 0.1892 

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)


print('----------------------------')


# ratio calculator
log_12CHp = 13.5633
del_log12CHp = 0.0047

log_13CHp = 0.6057
del_log13CHp = 1622243.7548

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 3.360469824606985 3.1031302147534094 2.8654972763642426 max, fit, min 10^13
# 0.09512616750371108 0.06153185387288103 0.03980155135426724 max, fit, min 10^13
# Ratio =  50.43128102663999
# upper bound = 84.43062419090103 lower bound = 30.12312333777615
# ----------------------------
# 3.6982817978026588 3.6584742279397116 3.619095138842978 max, fit, min 10^13
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[2], line 64
#      62 max_log13CHp = log_13CHp + del_log13CHp
#      63 min_log13CHp = log_13CHp - del_log13CHp
# ---> 64 print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')
#      66 ratio = 10**(log_12CHp - log_13CHp)
#      67 print('Ratio = ', ratio)
#
# OverflowError: (34, 'Result too large')

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 55879_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-55879')
plt.show()

# has only one component with good ratio

# ratio calculator for 183143
log_12CHp = 12.5968 
del_log12CHp = 0.0099

log_13CHp = 11.1582 
del_log13CHp = 0.1926

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.4042965170759654 0.39518458892843655 0.3862780230114958 max, fit, min 10^13
# 0.02242848815869291 0.014394613220781626 0.009238468875379456 max, fit, min 10^13
# Ratio =  27.45364414223407
# upper bound = 43.76228599453495 lower bound = 17.2226509552665

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 210121_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-210121')
plt.show()

# ratio calculator
log_12CHp = 12.7586 
del_log12CHp = 0.1064

log_13CHp = 10.9717 
del_log13CHp = 0.6834

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.6875 
del_log12CHp = 0.1104

log_13CHp = 11.2881 
del_log13CHp = 0.3523

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.7328245331389045 0.5735879248421334 0.4489520924135648 max, fit, min 10^13
# 0.045196000003048346 0.009369145856727323 0.0019422270572331665 max, fit, min 10^13
# Ratio =  61.220940906825604
# upper bound = 377.3114633583894 lower bound = 9.933447481708209
# ----------------------------
# 0.6279137596800942 0.4869675251658631 0.3776591401452659 max, fit, min 10^13
# 0.04369180633852877 0.019413328345375184 0.0086258122295348 max, fit, min 10^13
# Ratio =  25.084185282523844
# upper bound = 72.79474013242674 lower bound = 8.643706264262061

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 186841_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-186841')
plt.show()

# ratio calculator
log_12CHp = 13.4165 
del_log12CHp = 0.0205

log_13CHp = 11.4447 
del_log13CHp = 0.2183

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.7871 
del_log12CHp = 0.0780

log_13CHp = 8.2415 
del_log13CHp = 23.9146

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 2.735268726306708 2.6091557230141307 2.488857318282385 max, fit, min 10^13
# 0.04602565735813544 0.02784197248883559 0.016842245750827038 max, fit, min 10^13
# Ratio =  93.71303430676045
# upper bound = 162.40522592851923 lower bound = 54.075432294558155
# ----------------------------
# 0.7329932916517788 0.6124914068474847 0.5117996682024623 max, fit, min 10^13
# 1.4325177106937596e+19 1.7438133574658395e-05 2.1227556231773312e-29 max, fit, min 10^13
# Ratio =  35123.6790465681
# upper bound = 3.4530272050564057e+28 lower bound = 3.5727283815192664e-20

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 171957_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-171957')
plt.show()

# ratio calculator
log_12CHp = 13.0215 
del_log12CHp = 0.0292

log_13CHp = 10.6153 
del_log13CHp = 0.5434

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.7002 
del_log12CHp = 0.0617

log_13CHp = 11.1029 
del_log13CHp = 0.2996

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)


# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.9190 
# del_log12CHp = 0.0698

# log_13CHp = 9.8217 
# del_log13CHp = 5.3448

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 1.1238283926249286 1.0507514548655505 0.9824263447582707 max, fit, min 10^13
# 0.014411195175201065 0.004123822843217303 0.0011800488880689647 max, fit, min 10^13
# Ratio =  254.800338136199
# upper bound = 952.357486191919 lower bound = 68.17105263058544
# ----------------------------
# 0.577962951195467 0.5014180920308947 0.4350107606306975 max, fit, min 10^13
# 0.025263877101318954 0.012673600118311286 0.0063576995452718655 max, fit, min 10^13
# Ratio =  39.563982400425225
# upper bound = 90.90755973601964 lower bound = 17.218685749860096

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 185418_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-185418')
plt.show()

# ratio calculator
log_12CHp = 11.8670 
del_log12CHp = 0.2685

log_13CHp = 11.5522 
del_log13CHp = 0.1778

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 13.1102 
del_log12CHp = 0.0820

log_13CHp = 11.3176 
del_log13CHp = 0.2986

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)


print('----------------------------')

# ratio calculator
log_12CHp = 12.5998 
del_log12CHp = 0.2274

log_13CHp = 10.5014 
del_log13CHp = 1.4935

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.13661550756904112 0.07362070974947375 0.039673452893165595 max, fit, min 10^13
# 0.0537031796370251 0.03566153230426397 0.023680997938737902 max, fit, min 10^13
# Ratio =  2.0644292320739983
# upper bound = 5.768992840692851 lower bound = 0.738754262993641
# ----------------------------
# 1.5566823452755436 1.2888429491602222 1.0670874200130984 max, fit, min 10^13
# 0.0413237761199758 0.020777820975042688 0.010447202192208004 max, fit, min 10^13
# Ratio =  62.02974559788141
# upper bound = 149.00471117871038 lower bound = 25.822601906345906
# ----------------------------
# 0.67173812854738 0.39792387763422493 0.23572193636510114 max, fit, min 10^13
# 0.09883254980990303 0.0031724880873508837 0.00010183568757197832 max, fit, min 10^13
# Ratio =  125.42958923023174
# upper bound = 6596.293937452819 lower bound = 2.385063795465103

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 180554_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-180554')
plt.show()

# ratio calculator
log_12CHp = 11.8670 
del_log12CHp = 0.2685

log_13CHp = 11.5522 
del_log13CHp = 0.1778

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 13.1102 
del_log12CHp = 0.0820

log_13CHp = 11.3176 
del_log13CHp = 0.2986

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.13661550756904112 0.07362070974947375 0.039673452893165595 max, fit, min 10^13
# 0.0537031796370251 0.03566153230426397 0.023680997938737902 max, fit, min 10^13
# Ratio =  2.0644292320739983
# upper bound = 5.768992840692851 lower bound = 0.738754262993641
# ----------------------------
# 1.5566823452755436 1.2888429491602222 1.0670874200130984 max, fit, min 10^13
# 0.0413237761199758 0.020777820975042688 0.010447202192208004 max, fit, min 10^13
# Ratio =  62.02974559788141
# upper bound = 149.00471117871038 lower bound = 25.822601906345906

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 172694_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-172694')
plt.show()

# ratio calculator
log_12CHp = 12.1837 
del_log12CHp = 0.0972

log_13CHp = 11.0999 
del_log13CHp = 0.6438

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.8304 
del_log12CHp = 0.3486

log_13CHp = 10.6219 
del_log13CHp = 0.9924

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 13.0168 
del_log12CHp = 0.2392

log_13CHp = 10.6869 
del_log13CHp = 0.7825

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.19094135492272948 0.15265112173588713 0.12203938207443159 max, fit, min 10^13
# 0.055424272338339894 0.01258635566876438 0.002858248603672732 max, fit, min 10^13
# Ratio =  12.128301928946929
# upper bound = 66.8036204679249 lower bound = 2.201912211484471
# ----------------------------
# 1.510080154164143 0.6767059576741896 0.3032494347329631 max, fit, min 10^13
# 0.04114338313870813 0.004186971454370622 0.00042608868358278855 max, fit, min 10^13
# Ratio =  161.62182261066093
# upper bound = 3544.0513028099144 lower bound = 7.370551753379339
# ----------------------------
# 1.80301774085957 1.0394413751488005 0.5992389025834777 max, fit, min 10^13
# 0.029471347956087416 0.004862952191867838 0.0008024167763085828 max, fit, min 10^13
# Ratio =  213.7469862210502
# upper bound = 2246.9841036401626 lower bound = 20.332931614677047

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 164353_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-164353')
plt.show()

# ratio calculator
log_12CHp = 12.7919 
del_log12CHp = 0.0096

log_13CHp = 11.0390 
del_log13CHp = 0.1895

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.1856 
del_log12CHp = 0.0374

log_13CHp = 8.9365 
del_log13CHp = 2.3801

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 13.0168 
# del_log12CHp = 0.2392

# log_13CHp = 10.6869 
# del_log13CHp = 0.7825

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.633140361710817 0.6192984599180426 0.6057591738749939 max, fit, min 10^13
# 0.016923882444364192 0.010939563662720931 0.007071312006812994 max, fit, min 10^13
# Ratio =  56.61089226332161
# upper bound = 89.53647655495973 lower bound = 35.7931565565038
# ----------------------------
# 0.16710906143107104 0.1533204199034917 0.14066951820610413 max, fit, min 10^13
# 0.020730033312893706 8.639726606843925e-05 3.6008082917348275e-07 max, fit, min 10^13
# Ratio =  1774.5980501517208
# upper bound = 464087.63780800963 lower bound = 6.78578350950407

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 155806_plot.reg')
plt.plot(wavelengths, fluxes)
plt.plot(wavelengths,fitted_fluxes)
plt.title('HD-155806')
plt.show()

# ratio calculator
log_12CHp = 12.6315 
del_log12CHp = 0.2245

log_13CHp = 10.6561 
del_log13CHp = 2.6688

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.6507 
del_log12CHp = 0.1159

log_13CHp = 9.4962 
del_log13CHp = 35.9483

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.1653 
del_log12CHp = 0.1364

log_13CHp = 11.0256 
del_log13CHp = 0.9546

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.7177942912713644 0.42805541958620485 0.2552701302661247 max, fit, min 10^13
# 2.113002447024129 0.004530018754322407 9.711806033832934e-06 max, fit, min 10^13
# Ratio =  94.49307890342999
# upper bound = 73909.45502523327 lower bound = 0.12080919765409516
# ----------------------------
# 0.5842517205360304 0.4474041415755966 0.34260997248813757 max, fit, min 10^13
# 2.7829153738526376e+32 0.0003134728988014007 3.5310185572375718e-40 max, fit, min 10^13
# Ratio =  1427.2498301648955
# upper bound = 1.6546265930505458e+39 lower bound = 1.231118903963777e-33
# ----------------------------
# 0.20030878652699935 0.14631875596007735 0.10688087485777344 max, fit, min 10^13
# 0.09554324776409487 0.010607181496353167 0.0011776059735208115 max, fit, min 10^13
# Ratio =  13.794310581975322
# upper bound = 170.0983104969443 lower bound = 1.1186648701923154

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 153919_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-153919')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.0605 
del_log12CHp = 0.0391

log_13CHp = 11.5153 
del_log13CHp = 0.2995

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.9578 
del_log12CHp = 0.0368

log_13CHp = 10.3715 
del_log13CHp = 1.3948

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.9207 
del_log12CHp = 0.0543

log_13CHp = 10.8894 
del_log13CHp = 9.4358

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 1.2577664324512503 1.149476243419833 1.0505095382546576 max, fit, min 10^13
# 0.06528298441586142 0.03275668919368471 0.016436146363905512 max, fit, min 10^13
# Ratio =  35.09134383585521
# upper bound = 76.52441178142341 lower bound = 16.09162858675042
# ----------------------------
# 0.9876430227771067 0.9074025596228705 0.8336811846196365 max, fit, min 10^13
# 0.05838482731071984 0.0023523394933889427 9.477635452629594e-05 max, fit, min 10^13
# Ratio =  385.74472867247727
# upper bound = 10420.774545649809 lower bound = 14.279072543673813
# ----------------------------
# 0.9440608762859226 0.8331054969176099 0.7351906920715674 max, fit, min 10^13
# 21144625.616526023 0.007751754320690811 2.8418424680635887e-12 max, fit, min 10^13
# Ratio =  107.47315542417324
# upper bound = 332200284461.6503 lower bound = 3.476962446178114e-08

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 144217_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-144217')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 12.6462 
del_log12CHp = 0.0305

log_13CHp = 10.4389 
del_log13CHp = 0.9472

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 11.9727 
del_log12CHp = 0.1166

log_13CHp = 9.3270 
del_log13CHp = 11.9234

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 11.1810 
del_log12CHp = 0.3346

log_13CHp = 9.8275 
del_log13CHp = 3.2388

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.4750069893831198 0.442792238778708 0.41276227740834964 max, fit, min 10^13
# 0.024327641092246992 0.0027472614999306763 0.00031024157748720877 max, fit, min 10^13
# Ratio =  161.17586141322232
# upper bound = 1531.087461682032 lower bound = 16.966802323464623
# ----------------------------
# 0.1228287409057814 0.09390743968513635 0.07179595885446745 max, fit, min 10^13
# 177991802.0395332 0.00021232444620002193 2.5327947656899882e-16 max, fit, min 10^13
# Ratio =  442.2827487168864
# upper bound = 484953390498342.2 lower bound = 4.0336666088992726e-10
# ----------------------------
# 0.03277932453002275 0.015170503674593338 0.007021016602403131 max, fit, min 10^13
# 1.164930456990453 0.0006722023091115677 3.8788233380237445e-07 max, fit, min 10^13
# Ratio =  22.568359954972184
# upper bound = 84508.4234919649 lower bound = 0.006026983465211838

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 135591_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-135591')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 12.6462 
del_log12CHp = 0.0305

log_13CHp = 10.4389 
del_log13CHp = 0.9472

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 11.9727 
del_log12CHp = 0.1166

log_13CHp = 9.3270 
del_log13CHp = 11.9234

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 11.1810 
del_log12CHp = 0.3346

log_13CHp = 9.8275 
del_log13CHp = 3.2388

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.4750069893831198 0.442792238778708 0.41276227740834964 max, fit, min 10^13
# 0.024327641092246992 0.0027472614999306763 0.00031024157748720877 max, fit, min 10^13
# Ratio =  161.17586141322232
# upper bound = 1531.087461682032 lower bound = 16.966802323464623
# ----------------------------
# 0.1228287409057814 0.09390743968513635 0.07179595885446745 max, fit, min 10^13
# 177991802.0395332 0.00021232444620002193 2.5327947656899882e-16 max, fit, min 10^13
# Ratio =  442.2827487168864
# upper bound = 484953390498342.2 lower bound = 4.0336666088992726e-10
# ----------------------------
# 0.03277932453002275 0.015170503674593338 0.007021016602403131 max, fit, min 10^13
# 1.164930456990453 0.0006722023091115677 3.8788233380237445e-07 max, fit, min 10^13
# Ratio =  22.568359954972184
# upper bound = 84508.4234919649 lower bound = 0.006026983465211838

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 133518_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-133518')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 12.3663 
del_log12CHp = 0.3289

log_13CHp = 10.1156 
del_log13CHp = 2.5157

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.6879 
del_log12CHp = 0.1161

log_13CHp = 10.0726 
del_log13CHp = 2.8749

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.5161 
del_log12CHp = 0.3384

log_13CHp = 11.0488 
del_log13CHp = 0.3853

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.4956784065941198 0.23243418403925303 0.10899334970270669 max, fit, min 10^13
# 0.4278583381637382 0.0013049684141302246 3.980155135426732e-06 max, fit, min 10^13
# Ratio =  178.1147968965769
# upper bound = 124537.45890007268 lower bound = 0.2547416749442797
# ----------------------------
# 0.6367955209079162 0.4874162454431551 0.3730783093184734 max, fit, min 10^13
# 0.8861352236594994 0.0011819524358201651 1.5765218707500877e-06 max, fit, min 10^13
# Ratio =  412.3822843217321
# upper bound = 403924.31765309896 lower bound = 0.42101735644562316
# ----------------------------
# 0.7153193940753371 0.32817084854452594 0.15055666982669796 max, fit, min 10^13
# 0.027170648241126815 0.01118922481955243 0.004607867686902707 max, fit, min 10^13
# Ratio =  29.329185340084422
# upper bound = 155.23870099580847 lower bound = 5.541151189716853

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 75309_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-75309')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 12.7417 
del_log12CHp = 0.0347

log_13CHp = 10.1371 
del_log13CHp = 2.8773

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.6615 
del_log12CHp = 0.0601

log_13CHp = 10.6415 
del_log13CHp = 0.8298

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.5975854297155736 0.5516962093834984 0.5093308710571942 max, fit, min 10^13
# 1.0337130523505844 0.001371197459700924 1.81886304832359e-06 max, fit, min 10^13
# Ratio =  402.34628899023085
# upper bound = 328548.8867709728 lower bound = 0.49271978321161247
# ----------------------------
# 0.5267444883319067 0.4586696457982017 0.39939258717802983 max, fit, min 10^13
# 0.029600564950758277 0.004380261111703611 0.0006481865274740793 max, fit, min 10^13
# Ratio =  104.71285480508985
# upper bound = 812.6433765672041 lower bound = 13.492735285371593

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 63804_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-63804')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.5498 
del_log12CHp = 0.0093

log_13CHp = 11.9959 
del_log13CHp = 0.1074

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.6796 
del_log12CHp = 0.0587

log_13CHp = 11.1031 
del_log13CHp = 0.5197

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 3.623264175531318 3.5465002924732016 3.4713627588769747 max, fit, min 10^13
# 0.12685278312575757 0.0990603823670606 0.07735706787749398 max, fit, min 10^13
# Ratio =  35.80139918430678
# upper bound = 46.83817878502423 lower bound = 27.365286541924608
# ----------------------------
# 0.547393958674596 0.4781894606659089 0.4177341687248784 max, fit, min 10^13
# 0.04195657223387252 0.012679437870941718 0.0038317750036138357 max, fit, min 10^13
# Ratio =  37.71377450113986
# upper bound = 142.85649813946173 lower bound = 9.956346443087929

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 41117_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-41117')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.0320 
del_log12CHp = 0.0975

log_13CHp = 9.2147 
del_log13CHp = 9.7299

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.9263 
del_log12CHp = 0.1236

log_13CHp = 11.3517 
del_log13CHp = 0.3185

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 1.3474107253444054 1.076465213629835 0.8600030668888555 max, fit, min 10^13
# 880237.7705913467 0.00016394568852635746 3.053514593940289e-14 max, fit, min 10^13
# Ratio =  6565.98671978356
# upper bound = 44126552662245.24 lower bound = 9.770122296741511e-07
# ----------------------------
# 1.121760129747122 0.8439175140304747 0.6348922123377007 max, fit, min 10^13
# 0.04679505908852528 0.02247501550421252 0.010794437099844508 max, fit, min 10^13
# Ratio =  37.549140460984255
# upper bound = 103.92020624802018 lower bound = 13.567505302998626

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 27778_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-27778')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 12.7059 
del_log12CHp = 0.0209

log_13CHp = 11.1506 
del_log13CHp = 0.1639

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.3827 
del_log12CHp = 0.0486

log_13CHp = 11.3443 
del_log13CHp = 0.1326

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 0.5330893422367002 0.5080424479948439 0.4841723675840999 max, fit, min 10^13
# 0.020630036673107113 0.014144903860233187 0.009698397942067533 max, fit, min 10^13
# Ratio =  35.916995478714306
# upper bound = 54.96674248892026 lower bound = 23.46929262686464
# ----------------------------
# 0.2699603608615012 0.241379286937296 0.21582413053688596 max, fit, min 10^13
# 0.029984720157970546 0.022095304955730016 0.01628170943449453 max, fit, min 10^13
# Ratio =  10.924460532267906
# upper bound = 16.58059075108917 lower bound = 7.197803728026975

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 166937_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-166937')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# # ratio calculator
# log_12CHp = 13.0037 
# del_log12CHp = 0.0410

# log_13CHp = 11.1279 
# del_log13CHp = 0.3046

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.2787 
# del_log12CHp = 0.2634

# log_13CHp = 10.7239 
# del_log13CHp = 1.0323

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 143275_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-143275')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# # ratio calculator
# log_12CHp = 13.0037 
# del_log12CHp = 0.0410

# log_13CHp = 11.1279 
# del_log13CHp = 0.3046

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.2787 
# del_log12CHp = 0.2634

# log_13CHp = 10.7239 
# del_log13CHp = 1.0323

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 135591_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-135591')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# # ratio calculator
# log_12CHp = 13.0037 
# del_log12CHp = 0.0410

# log_13CHp = 11.1279 
# del_log13CHp = 0.3046

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.2787 
# del_log12CHp = 0.2634

# log_13CHp = 10.7239 
# del_log13CHp = 1.0323

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 104705_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-104705')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# # ratio calculator
# log_12CHp = 13.0037 
# del_log12CHp = 0.0410

# log_13CHp = 11.1279 
# del_log13CHp = 0.3046

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.2787 
# del_log12CHp = 0.2634

# log_13CHp = 10.7239 
# del_log13CHp = 1.0323

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 149038_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-149038')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.1491 
del_log12CHp = 0.0443

log_13CHp = 11.2923 
del_log13CHp = 0.2692

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 13.2900 
del_log12CHp = 0.0325

log_13CHp = 11.5211 
del_log13CHp = 0.1945

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 1.5609895654550638 1.4096133365221695 1.2729167461935627 max, fit, min 10^13
# 0.03643342500684958 0.01960198262928797 0.010546297058996503 max, fit, min 10^13
# Ratio =  71.9117735782512
# upper bound = 148.01304730208258 lower bound = 34.93815763832939
# ----------------------------
# 2.101357769046747 1.9498445997580414 1.8092559102538144 max, fit, min 10^13
# 0.051951728301106774 0.03319708878746799 0.021212897818830703 max, fit, min 10^13
# Ratio =  58.735409368008014
# upper bound = 99.0603823670602 lower bound = 34.82571166386529

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 147889_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-147889')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.4049 
del_log12CHp = 0.0284

log_13CHp = 11.6076 
del_log13CHp = 0.1975

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.9869 
del_log12CHp = 0.0783

log_13CHp = 11.7885 
del_log13CHp = 0.1637

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 2.712064412707171 2.5403876923166746 2.379578300956397 max, fit, min 10^13
# 0.0638410468710757 0.04051352202292635 0.025709877064152262 max, fit, min 10^13
# Ratio =  62.70468637308514
# upper bound = 105.48725713234353 lower bound = 37.273484969033404
# ----------------------------
# 1.1619836038697982 0.9702865247929224 0.8102144789817688 max, fit, min 10^13
# 0.08957771912192168 0.06144690317057627 0.04215023497210448 max, fit, min 10^13
# Ratio =  15.790649727284261
# upper bound = 27.567666102901033 lower bound = 9.044821490475872

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 149757_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-149757')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.4635 
del_log12CHp = 0.0120

log_13CHp = 11.6191 
del_log13CHp = 0.0955

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')

# ratio calculator
log_12CHp = 12.1261 
del_log12CHp = 0.2513

log_13CHp = 11.0177 
del_log13CHp = 0.3264

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# # ratio calculator
# log_12CHp = 12.5161 
# del_log12CHp = 0.3384

# log_13CHp = 11.0488 
# del_log13CHp = 0.3853

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)
# Out:
# 2.988821646959377 2.9073679594442274 2.8281341110474694 max, fit, min 10^13
# 0.05183224264170603 0.04160063884776205 0.033388737672512304 max, fit, min 10^13
# Ratio =  69.88757961347106
# upper bound = 89.51586239272417 lower bound = 54.563221016639055
# ----------------------------
# 0.23845146774529496 0.1336903314472802 0.07495489497919562 max, fit, min 10^13
# 0.022085132034348202 0.010415976706452617 0.004912471004503345 max, fit, min 10^13
# Ratio =  12.835121968394963
# upper bound = 48.54002548344866 lower bound = 3.3939074877442885

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 37903_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-37903')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 45314_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-45314')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 154043_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-154043')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 186745_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-186745')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 40111_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-40111')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 167971_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-167971')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()




# ratio calculator
log_12CHp = 13.3759 
del_log12CHp = 0.0150

log_13CHp = 12.0702 
del_log13CHp = 0.0681

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')




log_12CHp = 13.3562 
del_log12CHp = 0.0567

log_13CHp = 12.4283 
del_log13CHp = 0.0299

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')



# log_12CHp = 13.2711 
# del_log12CHp = 0.1808

# log_13CHp = 12.4248 
# del_log13CHp = 0.0407

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')




# log_12CHp = 12.6725 
# del_log12CHp = 0.0947

# log_13CHp = 12.6515 
# del_log13CHp = 0.2750

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')
# Out:
# 2.459801148788855 2.376293061927623 2.2956200012125723 max, fit, min 10^13
# 0.1374991457485029 0.11754387398615579 0.10048471382465814 max, fit, min 10^13
# Ratio =  20.216222090889236
# upper bound = 24.479356661960658 lower bound = 16.695521915543008
# ----------------------------
# 2.587617025712431 2.270910404006826 1.9929665061647184 max, fit, min 10^13
# 0.2872102929797832 0.26810196680906334 0.2502649325731083 max, fit, min 10^13
# Ratio =  8.470323552770209
# upper bound = 10.33951100982367 lower bound = 6.939049730731636
# ----------------------------

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 170938_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-170938')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()




# # ratio calculator
# log_12CHp = 13.3759 
# del_log12CHp = 0.0150

# log_13CHp = 12.0702 
# del_log13CHp = 0.0681

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')




# log_12CHp = 13.3562 
# del_log12CHp = 0.0567

# log_13CHp = 12.4283 
# del_log13CHp = 0.0299

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')



# log_12CHp = 13.2711 
# del_log12CHp = 0.1808

# log_13CHp = 12.4248 
# del_log13CHp = 0.0407

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')




# log_12CHp = 12.6725 
# del_log12CHp = 0.0947

# log_13CHp = 12.6515 
# del_log13CHp = 0.2750

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 147888_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-147888')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 303308_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-303308')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 43384_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-43384')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 111934_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-111934')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 157246_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-157246')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 149404_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-149404')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 37128_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-37128')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()

# %%
wavelengths, fluxes, errors,fitted_fluxes = read_reg_file('HD 147683_plot.reg')

# Create a figure with the overall size (10, 8)
fig = plt.figure(figsize=(7, 7))

# Create a GridSpec with 2 rows and 1 column, with different height ratios
grid = fig.add_gridspec(nrows=2, ncols=1, height_ratios=[6, 2])

# Add the first subplot (upper image), which will take up 6/8 of the height
ax1 = fig.add_subplot(grid[0, 0])
ax1.set_title('Fitting the spectral data of HD-147683')
ax1.plot(wavelengths, fluxes, label='data')  
ax1.plot(wavelengths, fitted_fluxes, label='composite fit')

# Add the second subplot (lower image), which will take up 2/8 of the height
ax2 = fig.add_subplot(grid[1, 0])
# ax2.set_title('Residuals after fitting')
ax2.plot(wavelengths, fluxes - fitted_fluxes)  

# Show the plot
plt.show()



# ratio calculator
log_12CHp = 13.1823 
del_log12CHp = 0.0202

log_13CHp = 11.4812 
del_log13CHp = 0.1571

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')




log_12CHp = 12.8531 
del_log12CHp = 0.0426

log_13CHp = 11.1247 
del_log13CHp = 0.3101

max_log12CHp = log_12CHp + del_log12CHp
min_log12CHp = log_12CHp - del_log12CHp
print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

max_log13CHp = log_13CHp + del_log13CHp
min_log13CHp = log_13CHp - del_log13CHp
print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

ratio = 10**(log_12CHp - log_13CHp)
print('Ratio = ', ratio)

max_ratio = 10**(max_log12CHp - min_log13CHp)
min_ratio = 10**(min_log12CHp - max_log13CHp)
print('upper bound =', max_ratio, 'lower bound =', min_ratio)

print('----------------------------')



# log_12CHp = 13.2711 
# del_log12CHp = 0.1808

# log_13CHp = 12.4248 
# del_log13CHp = 0.0407

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')




# log_12CHp = 12.6725 
# del_log12CHp = 0.0947

# log_13CHp = 12.6515 
# del_log13CHp = 0.2750

# max_log12CHp = log_12CHp + del_log12CHp
# min_log12CHp = log_12CHp - del_log12CHp
# print(10**(max_log12CHp)/10**13, 10**(log_12CHp)/10**13, 10**(min_log12CHp)/10**13, 'max, fit, min', '10^13')

# max_log13CHp = log_13CHp + del_log13CHp
# min_log13CHp = log_13CHp - del_log13CHp
# print(10**(max_log13CHp)/10**13, 10**(log_13CHp)/10**13, 10**(min_log13CHp)/10**13, 'max, fit, min', '10^13')

# ratio = 10**(log_12CHp - log_13CHp)
# print('Ratio = ', ratio)

# max_ratio = 10**(max_log12CHp - min_log13CHp)
# min_ratio = 10**(min_log12CHp - max_log13CHp)
# print('upper bound =', max_ratio, 'lower bound =', min_ratio)

# print('----------------------------')
# Out:
# 1.5940428807122198 1.521598249619051 1.4524460171418343 max, fit, min 10^13
# 0.04348104768927267 0.030283076942657753 0.021091137354107066 max, fit, min 10^13
# Ratio =  50.24582714960767
# upper bound = 75.57880136804536 lower bound = 33.40411729545724
# ----------------------------
# 0.7865023054586578 0.7130171895014065 0.6463979939995331 max, fit, min 10^13
# 0.027214477464543724 0.013326005862775782 0.006525292741192517 max, fit, min 10^13
# Ratio =  53.50569381731356
# upper bound = 120.53134420984186 lower bound = 23.751989904700185
# ----------------------------
